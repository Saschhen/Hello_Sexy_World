# %% [markdown]
# # Sexy_World_1.
#
# 1. Что это и зачем?
# 2. Моя первая программа на Python
# 3. Как и зачем писать комментарии
# 4. Познакомимся с библиотеками
# 5. Выгрузим топ постов из нашего любимого паблика во Вконтакте
# 6. Что дальше?

# %% [markdown]
# # 1. Что это и зачем?

# %% [markdown]
# Когда-то мы просто [писали бугуртики](https://vk.com/bugurt_thread) и новости, работали в пиаре и развивали бренд работодателя. Сейчас мы выросли, сделали первые уверенные шаги в сторону настоящей карьеры и хотим поделиться с вам кое-чем полезным. В своих новых проектах мы расскажем вам о том, как начаться закатываться в отрасль IT (аналитики данных) просто и весело.

# %% [markdown]
# # 2. Моя первая программа на Python

# %% [markdown]
# Начнем с простого -- объясним как запустить Python и сделаем первую прикольную штуку.
#
# Где бы вы ни находились и на какой платформе ни сидели бы -- вы почти наверняка можете установить туда интерпретатор Python. Если вы сидите под виндой -- [установить дистрибутив Python с python.org](https://www.python.org/ftp/python/3.8.0/python-3.8.0.exe). После установки вы сможете запустить интерпретатор языка Python через командную строку (Win+R -> python). Если вы на маке или одном из линуксов -- просто откройте Терминал и вбейте волшебное слово python.
#
# После запуска Python пришло время написать первую программу - вот так сразу. Первая программа, написанная программистом на новом языке, традиционно называется "Hello, World!".  Все, что она делает, -- выводит слова. В Python код такой проги выглядит так:

# %%
print("Hello, Sexy World!")
# Out:
# Hello, Sexy World!

# %% [markdown]
# Ура! Вы написали первую программу на Python. Это пример использования функции 'print', которая на самом деле ничего не печатает на бумаге, а лишь выводит значение на экране.
#
# Для того, чтобы вывести какое-либо значение в Python, вам потребуются:
#
# --> функция print()
#
# --> заключение символов в кавычки, если вы хотите напечатать текстовую строку

# %% [markdown]
# # 3. Как и зачем писать комментарии

# %% [markdown]
# Наша программа занимает всего одну строку, но со временем они будут становиться больше и сложнее. Хорошей идеей является добавление заметок (комментариев) прямо в тело кода.
#
# Комментарий в Python начинается с символа '#'. Все, что идет после этого символа -- для людей. Сам язык все это игнорирует. Вот новая версия вашей первой программы:

# %%
#---------------------------------------------------
# Эта программа показывает, насколько элегантен язык программирования Python!
# Форма его так же прекрасна, как перекаты ехидного YOBA-шара
#---------------------------------------------------

# print("Hello, World!") 
print("Hello, Sexy World!") # Ну разве это не легко?
# Out:
# Hello, Sexy World!

# %% [markdown]
# # 4. Познакомимся с библиотеками

# %% [markdown]
# Интересная часть starts here.
#
# Первый секрет всех хитрых аналитиков данных: на самом деле значительная часть всего необходимого функционала уже давно написана другими программистами. Очень важный навык -- найти эти куски кода и применить их у себя в проекте.
#
# Часто готовую функциональность можно найти в виде уже готовых библиотек для Python. Библиотеке -- это просто текстовый файл с расширением .py, который можно скачать и установить себе, а затем вызывать его когда нужно. Довольно просто, не правда ли? Вы тоже можете написать библиотеку, но чуть позже.
#
# Давайте попробуем установить библиотеку, которую написал какой-то умный человек.
# Вызовите консоль (Windows -> cmd.exe) и напишите:

# %%
pip install vktop

# %% [markdown]
# У вас установится библиотека vktop. Фактически просто скачается файл vktop.py и сохраниться в папочку lib в директории Python.
#
# Библиотеку можно запускать определенными способами все они подробно описаны на странице библиотеки в Гитхабе:
#
# https://github.com/yutkin/VK-Top

# %% [markdown]
# ![Alt text](img/pipinstallvktop.png)
#
# В моем случае по умолчанию терминал пытается выполнить команду на устаревшем Python 2, поэтому вручную указываю pip3, а не просто pip. Библиотека уже установлена, выводится сообщение requirements already satisfied

# %% [markdown]
# # 5. Выгрузим топ постов из нашего любимого паблика во Вконтакте

# %% [markdown]
# Функционал библиотеки довольно простой -- обращаться к VK-API и запрашивать самые популярные посты в каком-то сообществе.
#
# Давайте им и воспользуемся, например, чтобы понять какие БУШПРИТЫ были наиболее популярны:

# %%
vktop https://vk.com/bugurt_thread --likes -n 10

# %% [markdown]
# В примере выше мы запрашиваем топ-10 самых популярных ПОСТОВ С БУРГЕРАМИ за все время жизни паблика. Довольно просто, не правда ли? Использование библиотеки позволяет нам достичь результата без погружения в дебри алгоритомв сортировки, сетевые запросы и прочие сложности.

# %% [markdown]
# Результаты работы выглядят вот так:
#
# ![Alt text](img/vktopresults.png)

# %% [markdown]
# # 6. Это было просто. Что дальше?

# %% [markdown]
# Подписывайтесь на наш [канальчик.](https://t.me/bugurtthread) Расскажите, как вам такой формат?
#
# Нам есть чем поделиться, если вы нас поддержите и проект взлетит, мы сделаем еще много интересных материалов.
