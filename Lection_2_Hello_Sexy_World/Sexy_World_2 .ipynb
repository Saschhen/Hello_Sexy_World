# %% [markdown]
# # Sexy_World_2.
# 1. Что это и зачем?
# 2. Значения и Типы Данных
# 3. Операторы и Операнды
# 4. Input (Ввод)
# 5. Практика

# %% [markdown]
# # 1. Что это и зачем?

# %% [markdown]
# **Hello Sexy World!** В этом ноутбуке я собрала для вас вещи, на первый взгляд, унылые, однако, крайне нужные для приручения Python. Покажу, какие значения и типы данных есть в Python, как ими манипулировать, а чтобы не было совсем скучно, разбавлю все реальными задачками. Here we go!

# %% [markdown]
# # 1. Значения и Типы Данных

# %% [markdown]
# **Значение** - одна из фундаментальных вещей, как слово или число, которыми манипулирует программа. Некоторые значения, к примеру, равны 5 (результат, когда мы складываем 2 + 3) и "Hello, Sexy World!". Эти объекты классифицируются на разные типы данных: 4 - это целое число, а «Hello, Sexy World!» - это строка, называемая так, потому что она содержит последовательность букв. Вы (и интерпретатор Python) можете идентифицировать строки по кавычкам, в которые они заключены.
#
#
# Для выведения числовых значений достаточно обернуть нужное для вывода число (или манипуляцию с числами) в функцию print():

# %%
print(5)

# %%
print(3.2)

# %%
print(5+3)

# %% [markdown]
# Усложним задачу: установим значение пары переменных, как нас учили на уроках алгебры, а затем выведем результаты этих переменных, сложенных вместе:

# %%
x = 1
y = 2
x + y

# %% [markdown]
# Если запустить ячейку с какой-либо переменной, программа напечатает ее значение. Это значит, что Python хранит значение переменной до тех пор, пока мы не изменим ее.
#
# Кроме того, если вы измените что-то в предыдущей ячейке, вам придется перезапустить все ячейки ниже, чтобы отрразить изменения. Функция перезапуска всех функций полезна, поскольку она стирает состояние интерпретатора и перезапускает все ячейки в текущем ноутбуке.

# %%
x

# %% [markdown]
# Немного забегу вперед - и снова вернусь в русло.
#
# Python имеет традиционные программные структуры - **функции**. Можно рефакторить предыдущий код в изящную функцию - и вот вы уже написали еще одну программу!

# %%
# Оператор 'def' указывает на то, что вы пишете функцию
# def + название функции через нижнее подчеркивание + (переменные, с которыми происходят манипуляциии)
def add_numbers(x, y):
    return x + y

# чтобы вывести функцию, достаточно напечатать ее название и задать значение переменных
add_numbers(1, 2)

# %% [markdown]
# Когда вы вводите большое целое число, у вас может возникнуть желание использовать запятые между группами из трех цифр, как в 42 000. Это неправильное целое число в Python, но оно означает что-то еще, что допустимо:

# %%
print(42500)
print(42,500)

# %% [markdown]
# Ну, это совсем не то, что мы ожидали!
#
# Из-за запятой Python решил рассматривать это как пару значений. Фактически, оператор 'print' может печатать любое количество значений, если вы разделяете их запятыми. Обратите внимание, что значения разделяются пробелами при их отображении:

# %%
print(42, 17, 56, 34, 11, 4.35, 32)
print(3.4, "hello", 45)

# %% [markdown]
# Так что не забывайте не ставить запятые или пробелы в ваших целых числах, независимо от того, насколько они велики!

# %% [markdown]
# И снова к делу. Попоробуйте запустить следующий пример:

# %%
first = 5
second = 7
print(first * second)
first = '17'
second = '3.2'
print(first * second)

# %% [markdown]
# Питону что-то не нравится и он не исполнил умножение. В чем дело? Может, проблема в типе данных, которые мы скормили программе?
#
# Спойлер: в ошибке, которую вывел нам Юпитер, уже есть все подсказки. Python не может совершить манипуляции с нечисловыми данными.
#
# Если вы не уверены, к какому классу (типу данных) относится значение, в Python есть функция **type**, которая все вам расскажет:

# %%
print(type("Hello, Sexy World!"))
print(type(17))
print("Hello, Sexy World")
print(type(3.2))

# %% [markdown]
# А как насчет наших значений из предыдущего примера, '17' и '3.2'? Они выглядят как числа, но они заключены в кавычки, как строки. Доверимся машине:

# %%
print(type("17"))
print(type("3.2"))

# %% [markdown]
# Это строки!
#
# Строки в Python могут быть заключены либо в одинарные кавычки ('), либо в двойные кавычки ("), или даже в тройные (''' или """)

# %%
print(type('Это строка.'))
print(type("И это тоже."))
print(type("""и это."""))
print(type('''и даже это...'''))

# %% [markdown]
# Строки с двойными кавычками могут содержать одинарные кавычки внутри них, а строки с одинарными кавычками могут содержать двойные кавычки:

# %%
print('''"О нет", воскликнули вы, "нельзя умножать строку на строку!"''')

# %% [markdown]
# Строки в тройных кавычках могут даже занимать несколько строк:

# %%
print("""Это сообщение займет
несколько строк
текста.""")

# %% [markdown]
# Python не заботится о том, используете ли вы одинарные, двойные или тройные кавычки, чтобы вывести строку. После того, как он проанализировал текст вашей программы или команды, способ сохранения значения во всех случаях идентичен, и окружающие кавычки не являются частью значения.
#
# Поэтому те, кто пишет на Python, обычно предпочитают заключать свои строки в одинарные кавычки.

# %%
print('Это строка.')
print("""И это.""")

# %% [markdown]
# P.s. ну если уж вам неймется совершить манипуляции с числами в строке, в Python есть оператор **eval()**, который сделает магию:

# %%
eval("15 + 3.2")

# %% [markdown]
# По сути, eval просто обрабатывает произвольную строку, как если бы это был код Python.

# %% [markdown]
# # 3. Операторы и Операнды

# %% [markdown]
# Вы можете создавать сложные выражения из более простых, используя операторы.
#
# **Операторы** - это функционал, который представляет вычисления, такие как сложение, умножение и деление. Значения, над которыми работает оператор, называются операндами.
#
# Ниже приведены допустимые выражения Python, значение которых более или менее ясно:

# %%
20 + 32
(5 + 9) * (15 - 7)
print(7 + 5)
print(3 * 7, (17 - 2) * 8)
print(2 ** 16)  # две звёздочки означают возведение в степень

# %% [markdown]
# Токены **'+'**, **'-'** и **'*'**, а также использование скобок для группировки, означают в Python то же, что они значат в математике.
#
# Звездочка - это токен для умножения, а '**' - это токен для возведения в степень. Сложение, вычитание, умножение и возведение в степень все делают то, что вы ожидаете.
#
# Помните, что если вы хотите увидеть результаты вычислений, программа должна указать это словом **print**. Поэтому в предыдущей ячейке первые три вычисления происходят, но их результаты не выводятся.
#
# В Python 3, который мы используем, оператор деления **'/'** выдает результат с плавающей запятой, если результат не является целым числом (например, 1/2). Если вы хотите усеченное деление, вы можете использовать оператор **'//'**:

# %%
print(9 / 5) # один слэш — это деление с ответом-дробью
print(5 / 9)
print(9 // 5) # два слэша считают частное от деления нацело

# %% [markdown]
# Обратите особое внимание на примеры выше: 9 // 5 усекает, а не округляет, поэтому он выдает значение 1, а не 2.
#
# Оператор целочисленного деления '//' также работает с числами с плавающей запятой. Он усекает до ближайшего целого числа, но все равно дает результат с плавающей запятой. Таким образом, 7,0 // 3,0 составляет 2,0.

# %%
print(7.0 / 3.0)
print(7.0 // 3.0)

# %% [markdown]
# Оператор модуля, иногда называемый оператором остатка или целочисленным оператором остатка, работает с целыми числами (и целочисленными выражениями) и возвращает остаток, когда первый операнд делится на второй. В Python оператор модуля является знаком процента **(%)**:

# %%
print(7 // 3)    # Это оператор целочисленного деления
print(7 % 3)     # Это оператор остатка или модуля, процент считает остаток от деления нацело

# %% [markdown]
# В приведенном выше примере 7, деленное на 3, равно 2, когда мы используем целочисленное деление, а остаток равен 1.
#
# Оператор модуля оказывается на удивление полезным. Например, вы можете проверить, делится ли одно число на другое - если x%y равно нулю, то x делится на y. Кроме того, вы можете извлечь самую правую цифру или цифры из числа. Например, x%10 дает крайнюю правую цифру x (в базе 10). Точно так же x%100 возвращает последние две цифры.

# %% [markdown]
# # 4. Input (Ввод)

# %% [markdown]
# А что если вовлечь пользователя в вашу программу - собрать его персональные данные! В Python есть и такая встроенная функция для выполнения этой задачи - **input**.

# %%
n = input("Please enter your name: ")

# %%
print("Hello", n)
print("Hello,", n)
print("Hello,", n, "!")

# %% [markdown]
# Что мы сделали? Мы вернули введенный текст из функции ввода и - в случае выше - присвоили переменной n.
#
# А сейчас надо запомнить. Функция ввода возвращает СТРОКУ. Даже если вы попросите пользователя ввести его возраст, вы получите строку типа "17". Ваша задача как программиста - преобразовать эту строку в int или float, используя вот такую магию:

# %%
print(3.14, int(3.14)) # int() преобразовывает число в целое
print(3.9999, int(3.9999))
print(3.0, int(3.0))
print(-3.999, int(-3.999))

print("2345", int("2345"))        
print(17, int(17))
#print(int("23bottles")) # ValueError: invalid literal for int() with base 10: '23bottles'

print(float("123.45")) # float() преобразовывает число в целое c плавающей точкой
print(type(float("123.45")))

print(str(17)) # str() преобразовывает число в строку
print(str(123.45))
print(type(str(123.45)))

# %% [markdown]
# Вот пример правильной программы, которая считывает два числа и выводит их сумму:

# %%
a = int(input())
b = int(input())
s = a + b
print(s)

# %% [markdown]
# А вот вам пример интересной программы. Она превращает количество секунд в более понятные человеку часы, минуты и секунды. Вызов input() позволяет пользователю ввести количество секунд. Затем мы конвертируем эту строку в целое число. Оттуда мы используем операторы деления и модуля для вычисления результатов:

# %%
str_seconds = input("Please enter the number of seconds you wish to convert")
total_secs = int(str_seconds)

hours = total_secs // 3600
secs_still_remaining = total_secs % 3600
minutes =  secs_still_remaining // 60
secs_finally_remaining = secs_still_remaining  % 60

print("Hrs=", hours, "mins=", minutes, "secs=", secs_finally_remaining)

# %% [markdown]
# # 5. Практика

# %% [markdown]
# А теперь вы поработайте руками и головой (если, конечно, хотите). Решите задачки, а ответы для сверки найдите в репозитории ко второй неделе.

# %% [markdown]
# ### Arithmetic Operators

# %% [markdown]
# **Задача**
#
# Прочитайте два целых числа из input() и выведите три строки, где:
#
# 1. Первая строка содержит сумму двух чисел.
# 2. Вторая строка содержит разницу двух чисел (первое - второе).
# 3. Третья строка содержит произведение двух чисел.
#
# Ограничения:
#
# 1 <= a <= 10 ** 10
# 1 <= b <= 10 ** 10

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())

# %% [markdown]
# ### Python: Division

# %% [markdown]
# **Задача**
#
# Прочитайте два целых числа и выведите две строки:
#
# 1. Первая строка должна содержать целочисленное деление, **a // b**.
# 2. Во второй строке должно быть деление с плавающей запятой, **a / b**.
#
# Вам не нужно выполнять какие-либо операции округления или форматирования.

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())

# %% [markdown]
# ### String Split and Join

# %% [markdown]
# В Python строку можно разделить.
#
# **Пример**
#
# a = "this is a string"
#
# a = a.split(" ") # a превратилась в список строк.
#
# print(a)
#
# ['this', 'is', 'a', 'string']
#
# Также легко и сделать объединение:
#
# a = "-".join(a)
#
# print(a)
#
# this-is-a-string
#
# **Задача**
#
# Вам дана строка. Разбейте строку на разделитель **" " (пробел)** и соедините, используя **"-" дефис**.

# %%
def split_and_join(line):
    # write your code here

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)

# %%
def see_you_soon(flag=False):
    if (flag):
        print('Получилось объемно, но продуктивно. It is never late to learn. See you soon! Your Sasha')
    else:
        print('Turn the flag True!')
              
see_you_soon(flag=True)
